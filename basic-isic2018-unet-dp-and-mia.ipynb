# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import os
from glob import glob
import sys
import random
from random import sample

from tqdm import tqdm_notebook
# from tqdm.notebook import tqdm
from skimage.io import imread, imshow
from skimage.transform import resize
#from sklearn.metrics import jaccard_similarity_score
from sklearn.metrics import jaccard_score
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.datasets as dsets
from torchvision import transforms
from torch.autograd import Variable
from torch.utils.data import Dataset

from PIL import Image
#from tqdm.notebook import tqdm
# pip install ipywidgets

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# This kernel demonstrates a quick and naive implementation of a U-Net in Pytorch, trained on a GPU. Enjoy!

# %% [markdown]
# # Image Preparation

# %% [markdown]
# The following image preparation was taken almost verbatim from another excellent kernel of the TGS Salt Identification challenge: https://www.kaggle.com/jesperdramsch/intro-to-seismic-salt-and-how-to-geophysics. I take no credit for it.

# %%
# Set some parameters# Set s 
im_width = 128
im_height = 128
im_chan = 1
path_train = '../external/isic2018/train'
path_test = '../external/isic2018/val'

train_path_images = os.path.abspath(path_train + "/images/")
train_path_masks = os.path.abspath(path_train + "/masks/")

test_path_images = os.path.abspath(path_test + "/images/")
test_path_masks = os.path.abspath(path_test + "/masks/")

# %%
train_path_images_list = glob(os.path.join(train_path_images, "*.png"))
train_path_masks_list = glob(os.path.join(train_path_masks, "*.png"))
test_path_images_list = glob(os.path.join(test_path_images, "*.png"))
test_path_masks_list = glob(os.path.join(test_path_masks, "*.png"))

# %%
demos = []
for filename in os.listdir(train_path_images):
    if filename.endswith((".png", ".jpg", ".jpeg", ".bmp")):
        demos.append(filename) 
ids = sample(demos, 5)
plt.figure(figsize=(20,10))
for j, img_name in enumerate(ids):
    q = j+1
    img = imread(train_path_images + "/" + img_name)
    img_mask = imread(train_path_masks + "/" + img_name)
    
    plt.subplot(1,2*(1+len(ids)),q*2-1)
    plt.imshow(img)
    plt.subplot(1,2*(1+len(ids)),q*2)
    plt.imshow(img_mask)
plt.show()

# %%
train_ids = next(os.walk(train_path_images))[2]
test_ids = next(os.walk(test_path_images))[2]

# %%
# Get and resize train images and masks
X_train = np.zeros((len(train_ids), im_height, im_width, im_chan), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), im_height, im_width, 1), dtype=np.bool_)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm_notebook(enumerate(train_ids), total=len(train_ids)):
    img = imread(path_train + '/images/' + id_)
    x = resize(img, (128, 128, 1), mode='constant', preserve_range=True)
    X_train[n] = x
    mask = imread(path_train + '/masks/' + id_)
    Y_train[n] = resize(mask, (128, 128, 1), 
                        mode='constant', 
                        preserve_range=True)

print('Done!')
# Out:
# Getting and resizing train images and masks ...
#   0%|          | 0/1886 [00:00<?, ?it/s]
# Done!

# %%
# Check if training data looks all right
ix = random.randint(0, len(train_ids))
plt.imshow(np.dstack((X_train[ix],X_train[ix],X_train[ix])))
plt.show()
tmp = np.squeeze(Y_train[ix]).astype(np.float32)
plt.imshow(np.dstack((tmp,tmp,tmp)))
plt.show()

# %% [markdown]
# # Prepare Images for Pytorch

# %% [markdown]
# The following is what allows us to easily use our with Pytorch. We create a class with the following methods which then allows us to use a DataLoader.

# %%
# https://stackoverflow.com/questions/50052295/how-do-you-load-images-into-pytorch-dataloader
class Dataset(torch.utils.data.Dataset):

    def __init__(self,preprocessed_images,train=True, preprocessed_masks=None):
        """
        Args:
            text_file(string): path to text file
            root_dir(string): directory with all train images
        """
        self.train = train
        self.images = preprocessed_images
        if self.train:
            self.masks = preprocessed_masks

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        mask = None
        if self.train:
            mask = self.masks[idx]
        return (image, mask)

# %%
X_train_shaped = X_train.reshape(-1, 1, 128, 128)/255
Y_train_shaped = Y_train.reshape(-1, 1, 128, 128)

# %%
X_train_shaped = X_train_shaped.astype(np.float32)
Y_train_shaped = Y_train_shaped.astype(np.float32)

# %% [markdown]
# We set a random seed for reproducibility.

# %%
torch.cuda.manual_seed_all(4200)
np.random.seed(133700)

# %%
indices = list(range(len(X_train_shaped)))
np.random.shuffle(indices)

val_size = 1/10
split = np.int_(np.floor(val_size * len(X_train_shaped)))

train_idxs = indices[split:]
val_idxs = indices[:split]

# %% [markdown]
# You may need to tweak your batch_size based on how much memory you have on your GPU.

# %%
dataset_train = Dataset(X_train_shaped[train_idxs], 
                                      train=True, 
                                      preprocessed_masks=Y_train_shaped[train_idxs])
dataset_val = Dataset(X_train_shaped[val_idxs], 
                                      train=True, 
                                      preprocessed_masks=Y_train_shaped[val_idxs])

batch_size = 16

train_loader = torch.utils.data.DataLoader(dataset=dataset_train, 
                                           batch_size=batch_size, 
                                           shuffle=True)

val_loader = torch.utils.data.DataLoader(dataset=dataset_val, 
                                           batch_size=batch_size, 
                                           shuffle=False)

# %% [markdown]
# # Define U-Net Model

# %% [markdown]
# Here's the meat of the kernel, where we define our U-Net architecture. See also this excellent kernel from an older challenge: https://www.kaggle.com/mlagunas/naive-unet-with-pytorch-tensorboard-logging.

# %%
class double_conv(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=1):
        super(double_conv, self).__init__()
        self.conv = nn.Sequential(
                    nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size,
                              stride=stride, padding=padding),
                    nn.BatchNorm2d(out_channels),
                    nn.ReLU(inplace=True),
                    nn.Conv2d(out_channels, out_channels, kernel_size=kernel_size,
                              stride=stride, padding=padding),
                    nn.BatchNorm2d(out_channels),
                    nn.ReLU(inplace=True))
        
    def forward(self, x):
        x = self.conv(x)
        return x
        
start_fm = 16

class Unet(nn.Module):
    
    def __init__(self):
        super(Unet, self).__init__()
        
        # Input 128x128x1
        
        #Contracting Path
        
        #(Double) Convolution 1        
        self.double_conv1 = double_conv(1, start_fm, 3, 1, 1)
        #Max Pooling 1
        self.maxpool1 = nn.MaxPool2d(kernel_size=2)
        
        #Convolution 2
        self.double_conv2 = double_conv(start_fm, start_fm * 2, 3, 1, 1)
        #Max Pooling 2
        self.maxpool2 = nn.MaxPool2d(kernel_size=2)
        
        #Convolution 3
        self.double_conv3 = double_conv(start_fm * 2, start_fm * 4, 3, 1, 1)
        #Max Pooling 3
        self.maxpool3 = nn.MaxPool2d(kernel_size=2)
        
        #Convolution 4
        self.double_conv4 = double_conv(start_fm * 4, start_fm * 8, 3, 1, 1)
        #Max Pooling 4
        self.maxpool4 = nn.MaxPool2d(kernel_size=2)
        
        #Convolution 5
        self.double_conv5 = double_conv(start_fm * 8, start_fm * 16, 3, 1, 1)
        
        #Transposed Convolution 4
        self.t_conv4 = nn.ConvTranspose2d(start_fm * 16, start_fm * 8, 2, 2)
        # Expanding Path Convolution 4 
        self.ex_double_conv4 = double_conv(start_fm * 16, start_fm * 8, 3, 1, 1)
        
        #Transposed Convolution 3
        self.t_conv3 = nn.ConvTranspose2d(start_fm * 8, start_fm * 4, 2, 2)
        #Convolution 3
        self.ex_double_conv3 = double_conv(start_fm * 8, start_fm * 4, 3, 1, 1)
        
        #Transposed Convolution 2
        self.t_conv2 = nn.ConvTranspose2d(start_fm * 4, start_fm * 2, 2, 2)
        #Convolution 2
        self.ex_double_conv2 = double_conv(start_fm * 4, start_fm * 2, 3, 1, 1)
        
        #Transposed Convolution 1
        self.t_conv1 = nn.ConvTranspose2d(start_fm * 2, start_fm, 2, 2)
        #Convolution 1
        self.ex_double_conv1 = double_conv(start_fm * 2, start_fm, 3, 1, 1)
        
        # One by One Conv
        self.one_by_one = nn.Conv2d(start_fm, 1, 1, 1, 0)
        #self.final_act = nn.Sigmoid()
        
        
    def forward(self, inputs):
        # Contracting Path
        conv1 = self.double_conv1(inputs)
        maxpool1 = self.maxpool1(conv1)

        conv2 = self.double_conv2(maxpool1)
        maxpool2 = self.maxpool2(conv2)

        conv3 = self.double_conv3(maxpool2)
        maxpool3 = self.maxpool3(conv3)

        conv4 = self.double_conv4(maxpool3)
        maxpool4 = self.maxpool4(conv4)
            
        # Bottom
        conv5 = self.double_conv5(maxpool4)
        
        # Expanding Path
        t_conv4 = self.t_conv4(conv5)
        cat4 = torch.cat([conv4 ,t_conv4], 1)
        ex_conv4 = self.ex_double_conv4(cat4)
        
        t_conv3 = self.t_conv3(ex_conv4)
        cat3 = torch.cat([conv3 ,t_conv3], 1)
        ex_conv3 = self.ex_double_conv3(cat3)

        t_conv2 = self.t_conv2(ex_conv3)
        cat2 = torch.cat([conv2 ,t_conv2], 1)
        ex_conv2 = self.ex_double_conv2(cat2)
        
        t_conv1 = self.t_conv1(ex_conv2)
        cat1 = torch.cat([conv1 ,t_conv1], 1)
        ex_conv1 = self.ex_double_conv1(cat1)
        
        one_by_one = self.one_by_one(ex_conv1)
        
        return one_by_one

# %% [markdown]
# We define a BCEWithLogitsLoss since we're comparing pixel by pixel. In addition, we didn't include a final sigmoid activation as this loss function includes a sigmoid for us.

# %%
model = Unet()
# model.cuda();
model.cpu();

criterion = nn.BCEWithLogitsLoss()

learning_rate = 1e-3

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
# 差分隱私參數
noise_multiplier = 1.0   # 噪聲倍數，越大越保護隱私
max_grad_norm = 1.0      # 梯度裁剪的範圍
batch_size = 8               # 批次大小
sample_size = 1000           # 總樣本大小
delta = 1e-5                 # 隱私失效概率

# 設定隱私預算 (假設我們希望 ε 不超過 5.0)
privacy_budget = 5.0

# %%
import math

def compute_epsilon(steps, noise_multiplier, batch_size, sample_size, delta):
    """
    計算累積隱私損失 ε。
    
    參數:
        steps (int): 訓練步驟次數
        noise_multiplier (float): 噪聲倍率
        batch_size (int): 批次大小
        sample_size (int): 數據總量
        delta (float): 隱私失效概率
    
    返回:
        epsilon (float): 隱私損失 ε
    """
    if noise_multiplier == 0:
        return float('inf')
    
    # 每步驟的數據採樣率
    q = batch_size / sample_size
    
    # Renyi Differential Privacy 的 orders
    orders = torch.arange(2, 64).float()
    
    # 計算每個 order 的 RDP 值
    rdp = [(q**2) * (order / (2 * noise_multiplier**2)) for order in orders]
    rdp_sum = steps * torch.tensor(rdp)
    
    # 計算對應的 epsilon
    epsilon = min(rdp_sum + torch.log(torch.tensor(1 / delta)) / (orders - 1))
    return epsilon.item()

# %%
import torch.nn.utils as nn_utils

def apply_dp_sgd(model, noise_multiplier, max_grad_norm):
    """
    對模型的梯度進行差分隱私處理。
    
    參數:
        model (torch.nn.Module): 神經網絡模型
        noise_multiplier (float): 噪聲倍率
        max_grad_norm (float): 梯度裁剪上限
    """
    for param in model.parameters():
        if param.grad is not None:
            # 將梯度裁剪到 max_grad_norm 的範圍內
            param.grad.data = torch.clamp(param.grad.data, -max_grad_norm, max_grad_norm)
            
            # 添加高斯噪聲到梯度
            noise = torch.randn_like(param.grad) * noise_multiplier * max_grad_norm
            param.grad.data += noise

# %%
import numpy as np
from torch.autograd import Variable

mean_train_losses = []
mean_val_losses = []
steps = 0  # 初始化總步數

for epoch in range(60):
    train_losses = []
    val_losses = []
    
    # 訓練階段
    model.train()
    for images, masks in train_loader:
        steps += 1  # 每次訓練步驟累積總步數
        # images = Variable(images.cuda())
        # masks = Variable(masks.cuda())
        # 將數據移動到 CPU 或 GPU
        images = Variable(images.cpu())
        masks = Variable(masks.cpu())
        
        # 前向傳播
        outputs = model(images)
        
        # 計算損失
        loss = criterion(outputs, masks)
        train_losses.append(loss.data.item())  # 儲存每個批次的損失

        # 反向傳播
        optimizer.zero_grad()
        loss.backward()
        
        # 應用差分隱私的梯度處理
        apply_dp_sgd(model, noise_multiplier, max_grad_norm)
        
        # 更新參數
        optimizer.step()
    
    # 每個 epoch 結束後，計算累積的 epsilon
    epsilon = compute_epsilon(steps, noise_multiplier, batch_size, sample_size, delta)
    print(f"Epoch {epoch + 1}: ε = {epsilon:.2f}, δ = {delta}")
    
    # 檢查是否超過隱私預算
    if epsilon > privacy_budget:
        print(f"達到隱私預算: ε = {epsilon:.2f}, 停止訓練")
        break

    # 訓練階段平均損失
    mean_train_loss = np.mean(train_losses)
    mean_train_losses.append(mean_train_loss)

    # 驗證階段
    model.eval()
    with torch.no_grad():
        for images, masks in val_loader:
            images = Variable(images.cpu())
            masks = Variable(masks.cpu())
            outputs = model(images)
            loss = criterion(outputs, masks)
            val_losses.append(loss.data.item())  # 儲存每個批次的驗證損失

    # 驗證階段平均損失
    mean_val_loss = np.mean(val_losses)
    mean_val_losses.append(mean_val_loss)

    # Print train and validation loss
    print(f'Epoch: {epoch + 1}. Train Loss: {mean_train_loss:.4f}. Val Loss: {mean_val_loss:.4f}')
# Out:
# Epoch 1: ε = 0.40, δ = 1e-05
# Epoch: 1. Train Loss: 0.6994. Val Loss: 0.6757
# Epoch 2: ε = 0.57, δ = 1e-05
# Epoch: 2. Train Loss: 0.6590. Val Loss: 0.6490
# Epoch 3: ε = 0.70, δ = 1e-05
# Epoch: 3. Train Loss: 0.6301. Val Loss: 0.6260
# Epoch 4: ε = 0.81, δ = 1e-05
# Epoch: 4. Train Loss: 0.6052. Val Loss: 0.5983
# Epoch 5: ε = 0.91, δ = 1e-05
# Epoch: 5. Train Loss: 0.5835. Val Loss: 0.5896
# Epoch 6: ε = 0.99, δ = 1e-05
# Epoch: 6. Train Loss: 0.5745. Val Loss: 0.5732
# Epoch 7: ε = 1.07, δ = 1e-05
# Epoch: 7. Train Loss: 0.5685. Val Loss: 0.5665
# Epoch 8: ε = 1.15, δ = 1e-05
# Epoch: 8. Train Loss: 0.5549. Val Loss: 0.5488
# Epoch 9: ε = 1.22, δ = 1e-05
# Epoch: 9. Train Loss: 0.5436. Val Loss: 0.5475
# Epoch 10: ε = 1.29, δ = 1e-05
# Epoch: 10. Train Loss: 0.5317. Val Loss: 0.5210
# Epoch 11: ε = 1.36, δ = 1e-05
# Epoch: 11. Train Loss: 0.5246. Val Loss: 0.5147
# Epoch 12: ε = 1.42, δ = 1e-05
# Epoch: 12. Train Loss: 0.5125. Val Loss: 0.5187
# Epoch 13: ε = 1.48, δ = 1e-05
# Epoch: 13. Train Loss: 0.5109. Val Loss: 0.5213
# Epoch 14: ε = 1.53, δ = 1e-05
# Epoch: 14. Train Loss: 0.5079. Val Loss: 0.5219
# Epoch 15: ε = 1.59, δ = 1e-05
# Epoch: 15. Train Loss: 0.5032. Val Loss: 0.5170
# Epoch 16: ε = 1.64, δ = 1e-05
# Epoch: 16. Train Loss: 0.5052. Val Loss: 0.5151
# Epoch 17: ε = 1.70, δ = 1e-05
# Epoch: 17. Train Loss: 0.4983. Val Loss: 0.5098
# Epoch 18: ε = 1.75, δ = 1e-05
# Epoch: 18. Train Loss: 0.4936. Val Loss: 0.5172
# Epoch 19: ε = 1.80, δ = 1e-05
# Epoch: 19. Train Loss: 0.4923. Val Loss: 0.5016
# Epoch 20: ε = 1.84, δ = 1e-05
# Epoch: 20. Train Loss: 0.4899. Val Loss: 0.4978
# Epoch 21: ε = 1.89, δ = 1e-05
# Epoch: 21. Train Loss: 0.4882. Val Loss: 0.4953
# Epoch 22: ε = 1.94, δ = 1e-05
# Epoch: 22. Train Loss: 0.4899. Val Loss: 0.4823
# Epoch 23: ε = 1.98, δ = 1e-05
# Epoch: 23. Train Loss: 0.4797. Val Loss: 0.4853
# Epoch 24: ε = 2.03, δ = 1e-05
# Epoch: 24. Train Loss: 0.4761. Val Loss: 0.4868
# Epoch 25: ε = 2.07, δ = 1e-05
# Epoch: 25. Train Loss: 0.4761. Val Loss: 0.4899
# Epoch 26: ε = 2.11, δ = 1e-05
# Epoch: 26. Train Loss: 0.4756. Val Loss: 0.4945
# Epoch 27: ε = 2.16, δ = 1e-05
# Epoch: 27. Train Loss: 0.4774. Val Loss: 0.4931
# Epoch 28: ε = 2.20, δ = 1e-05
# Epoch: 28. Train Loss: 0.4754. Val Loss: 0.4878
# Epoch 29: ε = 2.24, δ = 1e-05
# Epoch: 29. Train Loss: 0.4738. Val Loss: 0.4839
# Epoch 30: ε = 2.28, δ = 1e-05
# Epoch: 30. Train Loss: 0.4782. Val Loss: 0.4871
# Epoch 31: ε = 2.32, δ = 1e-05
# Epoch: 31. Train Loss: 0.4762. Val Loss: 0.4852
# Epoch 32: ε = 2.36, δ = 1e-05
# Epoch: 32. Train Loss: 0.4745. Val Loss: 0.4820
# Epoch 33: ε = 2.39, δ = 1e-05
# Epoch: 33. Train Loss: 0.4708. Val Loss: 0.4785
# Epoch 34: ε = 2.43, δ = 1e-05
# Epoch: 34. Train Loss: 0.4675. Val Loss: 0.4884
# Epoch 35: ε = 2.47, δ = 1e-05
# Epoch: 35. Train Loss: 0.4656. Val Loss: 0.4880
# Epoch 36: ε = 2.51, δ = 1e-05
# Epoch: 36. Train Loss: 0.4688. Val Loss: 0.4874
# Epoch 37: ε = 2.54, δ = 1e-05
# Epoch: 37. Train Loss: 0.4637. Val Loss: 0.4843
# Epoch 38: ε = 2.58, δ = 1e-05
# Epoch: 38. Train Loss: 0.4654. Val Loss: 0.4732
# Epoch 39: ε = 2.61, δ = 1e-05
# Epoch: 39. Train Loss: 0.4663. Val Loss: 0.4755
# Epoch 40: ε = 2.65, δ = 1e-05
# Epoch: 40. Train Loss: 0.4629. Val Loss: 0.4749
# Epoch 41: ε = 2.68, δ = 1e-05
# Epoch: 41. Train Loss: 0.4592. Val Loss: 0.4707
# Epoch 42: ε = 2.72, δ = 1e-05
# Epoch: 42. Train Loss: 0.4572. Val Loss: 0.4702
# Epoch 43: ε = 2.75, δ = 1e-05
# Epoch: 43. Train Loss: 0.4576. Val Loss: 0.4623
# Epoch 44: ε = 2.79, δ = 1e-05
# Epoch: 44. Train Loss: 0.4601. Val Loss: 0.4648
# Epoch 45: ε = 2.82, δ = 1e-05
# Epoch: 45. Train Loss: 0.4600. Val Loss: 0.4768
# Epoch 46: ε = 2.85, δ = 1e-05
# Epoch: 46. Train Loss: 0.4558. Val Loss: 0.4706
# Epoch 47: ε = 2.89, δ = 1e-05
# Epoch: 47. Train Loss: 0.4574. Val Loss: 0.4693
# Epoch 48: ε = 2.92, δ = 1e-05
# Epoch: 48. Train Loss: 0.4554. Val Loss: 0.4803
# Epoch 49: ε = 2.95, δ = 1e-05
# Epoch: 49. Train Loss: 0.4578. Val Loss: 0.4697
# Epoch 50: ε = 2.98, δ = 1e-05
# Epoch: 50. Train Loss: 0.4535. Val Loss: 0.4618
# Epoch 51: ε = 3.01, δ = 1e-05
# Epoch: 51. Train Loss: 0.4552. Val Loss: 0.4680
# Epoch 52: ε = 3.04, δ = 1e-05
# Epoch: 52. Train Loss: 0.4544. Val Loss: 0.4754
# Epoch 53: ε = 3.07, δ = 1e-05
# Epoch: 53. Train Loss: 0.4503. Val Loss: 0.4545
# Epoch 54: ε = 3.10, δ = 1e-05
# Epoch: 54. Train Loss: 0.4472. Val Loss: 0.4594
# Epoch 55: ε = 3.13, δ = 1e-05
# Epoch: 55. Train Loss: 0.4533. Val Loss: 0.4711
# Epoch 56: ε = 3.16, δ = 1e-05
# Epoch: 56. Train Loss: 0.4518. Val Loss: 0.4638
# Epoch 57: ε = 3.20, δ = 1e-05
# Epoch: 57. Train Loss: 0.4535. Val Loss: 0.4851
# Epoch 58: ε = 3.23, δ = 1e-05
# Epoch: 58. Train Loss: 0.4512. Val Loss: 0.4595
# Epoch 59: ε = 3.26, δ = 1e-05
# Epoch: 59. Train Loss: 0.4516. Val Loss: 0.4693
# Epoch 60: ε = 3.29, δ = 1e-05
# Epoch: 60. Train Loss: 0.4499. Val Loss: 0.4601

# %% [markdown]
# We note that around 11-13 epochs is when we start to worry about overfitting to our training data as we see a rise in our validation loss.

# %%
train_loss_series = pd.Series(mean_train_losses)
val_loss_series = pd.Series(mean_val_losses)
train_loss_series.plot(label="train")
val_loss_series.plot(label="validation")
plt.legend()

# %% [markdown]
# Finally we compute our IOU score for various thresholds.

# %%
y_pred_true_pairs = []
for images, masks in val_loader:
    images = Variable(images.cpu())
    y_preds = model(images)
    for i, _ in enumerate(images):
        y_pred = y_preds[i] 
        y_pred = torch.sigmoid(y_pred)
        y_pred = y_pred.cpu().data.numpy()
        y_pred_true_pairs.append((y_pred, masks[i].numpy()))

# %% [markdown]
# We use a method to calculate the IOU score as found in this kernel here: https://www.kaggle.com/leighplt/goto-pytorch-fix-for-v0-3.

# %%
# https://www.kaggle.com/leighplt/goto-pytorch-fix-for-v0-3
for threshold in np.linspace(0, 1, 11):
    
    ious = []
    for y_pred, mask in y_pred_true_pairs:
        prediction = (y_pred > threshold).astype(int)
        iou = jaccard_score(mask.flatten(), prediction.flatten(), zero_division=1)
        ious.append(iou)
        
    accuracies = [np.mean(ious > iou_threshold)
                 for iou_threshold in np.linspace(0.5, 0.95, 10)]
    print('Threshold: %.1f, Metric: %.3f' % (threshold, np.mean(accuracies)))
# Out:
# Threshold: 0.0, Metric: 0.068
# Threshold: 0.1, Metric: 0.074
# Threshold: 0.2, Metric: 0.078
# Threshold: 0.3, Metric: 0.097
# Threshold: 0.4, Metric: 0.079
# Threshold: 0.5, Metric: 0.033
# Threshold: 0.6, Metric: 0.001
# Threshold: 0.7, Metric: 0.000
# Threshold: 0.8, Metric: 0.000
# Threshold: 0.9, Metric: 0.000
# Threshold: 1.0, Metric: 0.000

# %% [markdown]
# # Reference
#
# - https://www.kaggle.com/code/erikistre/pytorch-basic-u-net/notebook

# %%
# Model Inversion Attack
def model_inversion_attack(model, target_shape, iterations=3000, lr=0.01):
    model.eval()
    reconstructed_image = torch.randn(target_shape, requires_grad=True)  # 隨機初始化攻擊影像
    # optimizer_attack = optim.Adam([reconstructed_image], lr=lr)
    optimizer_attack = torch.optim.Adam([reconstructed_image], lr=learning_rate)
    for i in range(iterations):
        optimizer_attack.zero_grad()
        output = model(reconstructed_image)
        loss = -torch.mean(output)  # 嘗試最大化模型輸出
        loss.backward()
        optimizer_attack.step()

        if i % 100 == 0:
            print(f"Attack Iteration {i}, Loss: {loss.item()}")

    return reconstructed_image.detach()

def model_inversion_attack_no_randn(model, initial_image, iterations=3000, lr=0.01):
    model.eval()
    
    # 將指定的初始影像作為攻擊的開始影像
    reconstructed_image = initial_image.clone().detach().requires_grad_(True)
    optimizer_attack = torch.optim.Adam([reconstructed_image], lr=learning_rate)
    
    # 印出選取的初始影像
    plt.imshow(initial_image[0][0].cpu().detach().numpy(), cmap='gray')
    plt.title("Initial Image for Attack")
    plt.show()
    
    # 進行攻擊
    for i in range(iterations):
        optimizer_attack.zero_grad()
        output = model(reconstructed_image)
        loss = -torch.mean(output)  # 最大化模型輸出
        loss.backward()
        optimizer_attack.step()

        if i % 100 == 0:
            print(f"Attack Iteration {i}, Loss: {loss.item()}")

    return reconstructed_image.detach()

# %%
# 執行攻擊並顯示結果
reconstructed_image = model_inversion_attack(model, (1, 1, im_height, im_width))

plt.imshow(reconstructed_image[0][0].cpu().detach().numpy(), cmap='gray')
plt.title("Reconstructed Image")
plt.show()
# Out:
# Attack Iteration 0, Loss: 63.96113204956055
# Attack Iteration 100, Loss: 52.13499450683594
# Attack Iteration 200, Loss: 45.31524658203125
# Attack Iteration 300, Loss: 40.26490020751953
# Attack Iteration 400, Loss: 36.15457534790039
# Attack Iteration 500, Loss: 32.76637649536133
# Attack Iteration 600, Loss: 29.84283447265625
# Attack Iteration 700, Loss: 27.30130958557129
# Attack Iteration 800, Loss: 25.003049850463867
# Attack Iteration 900, Loss: 22.89849853515625
# Attack Iteration 1000, Loss: 20.961868286132812
# Attack Iteration 1100, Loss: 19.178874969482422
# Attack Iteration 1200, Loss: 17.569595336914062
# Attack Iteration 1300, Loss: 16.105735778808594
# Attack Iteration 1400, Loss: 14.7625732421875
# Attack Iteration 1500, Loss: 13.509650230407715
# Attack Iteration 1600, Loss: 12.325478553771973
# Attack Iteration 1700, Loss: 11.217022895812988
# Attack Iteration 1800, Loss: 10.195568084716797
# Attack Iteration 1900, Loss: 9.237203598022461
# Attack Iteration 2000, Loss: 8.35021686553955
# Attack Iteration 2100, Loss: 7.525757312774658
# Attack Iteration 2200, Loss: 6.767206192016602
# Attack Iteration 2300, Loss: 6.0582051277160645
# Attack Iteration 2400, Loss: 5.375827789306641
# Attack Iteration 2500, Loss: 4.739397048950195
# Attack Iteration 2600, Loss: 4.147870063781738
# Attack Iteration 2700, Loss: 3.6074776649475098
# Attack Iteration 2800, Loss: 3.117309093475342
# Attack Iteration 2900, Loss: 2.673837184906006

# %%
# 選取指定的初始影像，例如訓練數據中的第一張
initial_image = torch.tensor(X_train_shaped[0:1], dtype=torch.float32).to('cpu')  # 假設使用 CPU
# 執行攻擊並顯示初始影像
reconstructed_image = model_inversion_attack_no_randn(model, initial_image)

# 顯示攻擊結果影像
plt.imshow(reconstructed_image[0][0].cpu().detach().numpy(), cmap='gray')
plt.title("Reconstructed Image with Specified Initial Image")
plt.show()
# Out:
# Attack Iteration 0, Loss: 0.937849760055542
# Attack Iteration 100, Loss: 0.5065602660179138
# Attack Iteration 200, Loss: 0.35975369811058044
# Attack Iteration 300, Loss: 0.2791539430618286
# Attack Iteration 400, Loss: 0.22549471259117126
# Attack Iteration 500, Loss: 0.18788394331932068
# Attack Iteration 600, Loss: 0.16116659343242645
# Attack Iteration 700, Loss: 0.14086993038654327
# Attack Iteration 800, Loss: 0.12413019686937332
# Attack Iteration 900, Loss: 0.10976028442382812
# Attack Iteration 1000, Loss: 0.09744958579540253
# Attack Iteration 1100, Loss: 0.08717665076255798
# Attack Iteration 1200, Loss: 0.07826817035675049
# Attack Iteration 1300, Loss: 0.06971898674964905
# Attack Iteration 1400, Loss: 0.0627942681312561
# Attack Iteration 1500, Loss: 0.056435368955135345
# Attack Iteration 1600, Loss: 0.04972119629383087
# Attack Iteration 1700, Loss: 0.043864406645298004
# Attack Iteration 1800, Loss: 0.037912845611572266
# Attack Iteration 1900, Loss: 0.032031506299972534
# Attack Iteration 2000, Loss: 0.026945732533931732
# Attack Iteration 2100, Loss: 0.021801874041557312
# Attack Iteration 2200, Loss: 0.016675636172294617
# Attack Iteration 2300, Loss: 0.011209516786038876
# Attack Iteration 2400, Loss: 0.006772432941943407
# Attack Iteration 2500, Loss: 0.0019789841026067734
# Attack Iteration 2600, Loss: -0.0017264988273382187
# Attack Iteration 2700, Loss: -0.005526126362383366
# Attack Iteration 2800, Loss: -0.00899564940482378
# Attack Iteration 2900, Loss: -0.012092767283320427

# %%
model_ndp = Unet()
# model.cuda();
model_ndp.cpu();

criterion = nn.BCEWithLogitsLoss()

learning_rate = 1e-3

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
mean_train_losses = []
mean_val_losses = []
for epoch in range(60):
    train_losses = []
    val_losses = []
    for images, masks in train_loader:        
        # images = Variable(images.cuda())
        # masks = Variable(masks.cuda())
        images = Variable(images.cpu())
        masks = Variable(masks.cpu())
        outputs = model_ndp(images)        
        
        loss = criterion(outputs, masks)
        train_losses.append(loss.data)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    for images, masks in val_loader:
        # images = Variable(images.cuda())
        # masks = Variable(masks.cuda())
        images = Variable(images.cpu())
        masks = Variable(masks.cpu())
        
        outputs = model_ndp(images)
        loss = criterion(outputs, masks)
        val_losses.append(loss.data)
    
    mean_train_losses.append(np.mean(train_losses))
    mean_val_losses.append(np.mean(val_losses))
    # Print Loss
    print('Epoch: {}. Train Loss: {}. Val Loss: {}'.format(epoch+1, np.mean(train_losses), np.mean(val_losses)))
# Out:
# Epoch: 1. Train Loss: 0.7074131965637207. Val Loss: 0.7053213119506836
# Epoch: 2. Train Loss: 0.708092212677002. Val Loss: 0.7053213119506836
# Epoch: 3. Train Loss: 0.7075931429862976. Val Loss: 0.7053213119506836
# Epoch: 4. Train Loss: 0.7071089148521423. Val Loss: 0.7053213119506836
# Epoch: 5. Train Loss: 0.7071901559829712. Val Loss: 0.7053213119506836
# Epoch: 6. Train Loss: 0.7069445252418518. Val Loss: 0.7053213119506836
# Epoch: 7. Train Loss: 0.7069849967956543. Val Loss: 0.7053213119506836
# Epoch: 8. Train Loss: 0.7075599431991577. Val Loss: 0.7053213119506836
# Epoch: 9. Train Loss: 0.7073894739151001. Val Loss: 0.7053213119506836
# Epoch: 10. Train Loss: 0.7072746157646179. Val Loss: 0.7053213119506836
# Epoch: 11. Train Loss: 0.7074805498123169. Val Loss: 0.7053213119506836
# Epoch: 12. Train Loss: 0.7076785564422607. Val Loss: 0.7053213119506836
# Epoch: 13. Train Loss: 0.7079489231109619. Val Loss: 0.7053213119506836
# Epoch: 14. Train Loss: 0.70734041929245. Val Loss: 0.7053213119506836
# Epoch: 15. Train Loss: 0.7072734832763672. Val Loss: 0.7053213119506836
# Epoch: 16. Train Loss: 0.7072657942771912. Val Loss: 0.7053213119506836
# Epoch: 17. Train Loss: 0.7070860862731934. Val Loss: 0.7053213119506836
# Epoch: 18. Train Loss: 0.7072834968566895. Val Loss: 0.7053213119506836
# Epoch: 19. Train Loss: 0.7077752351760864. Val Loss: 0.7053213119506836
# Epoch: 20. Train Loss: 0.7075836062431335. Val Loss: 0.7053213119506836
# Epoch: 21. Train Loss: 0.7073205709457397. Val Loss: 0.7053213119506836
# Epoch: 22. Train Loss: 0.7076470851898193. Val Loss: 0.7053213119506836
# Epoch: 23. Train Loss: 0.7078324556350708. Val Loss: 0.7053213119506836
# Epoch: 24. Train Loss: 0.7073193192481995. Val Loss: 0.7053213119506836
# Epoch: 25. Train Loss: 0.7072548270225525. Val Loss: 0.7053213119506836
# Epoch: 26. Train Loss: 0.707298219203949. Val Loss: 0.7053213119506836
# Epoch: 27. Train Loss: 0.7072055339813232. Val Loss: 0.7053213119506836
# Epoch: 28. Train Loss: 0.7072870135307312. Val Loss: 0.7053213119506836
# Epoch: 29. Train Loss: 0.7072631120681763. Val Loss: 0.7053213119506836
# Epoch: 30. Train Loss: 0.7074114084243774. Val Loss: 0.7053213119506836
# Epoch: 31. Train Loss: 0.7072446346282959. Val Loss: 0.7053213119506836
# Epoch: 32. Train Loss: 0.7068567872047424. Val Loss: 0.7053213119506836
# Epoch: 33. Train Loss: 0.7069224715232849. Val Loss: 0.7053213119506836
# Epoch: 34. Train Loss: 0.7078817486763. Val Loss: 0.7053213119506836
# Epoch: 35. Train Loss: 0.7076036930084229. Val Loss: 0.7053213119506836
# Epoch: 36. Train Loss: 0.7078354954719543. Val Loss: 0.7053213119506836
# Epoch: 37. Train Loss: 0.7076860666275024. Val Loss: 0.7053213119506836
# Epoch: 38. Train Loss: 0.7074702382087708. Val Loss: 0.7053213119506836
# Epoch: 39. Train Loss: 0.7074769735336304. Val Loss: 0.7053213119506836
# Epoch: 40. Train Loss: 0.7072957754135132. Val Loss: 0.7053213119506836
# Epoch: 41. Train Loss: 0.707544207572937. Val Loss: 0.7053213119506836
# Epoch: 42. Train Loss: 0.7069684267044067. Val Loss: 0.7053213119506836
# Epoch: 43. Train Loss: 0.7067309021949768. Val Loss: 0.7053213119506836
# Epoch: 44. Train Loss: 0.7074885964393616. Val Loss: 0.7053213119506836
# Epoch: 45. Train Loss: 0.7075340747833252. Val Loss: 0.7053213119506836
# Epoch: 46. Train Loss: 0.7077799439430237. Val Loss: 0.7053213119506836
# Epoch: 47. Train Loss: 0.7074642181396484. Val Loss: 0.7053213119506836
# Epoch: 48. Train Loss: 0.7073363065719604. Val Loss: 0.7053213119506836
# Epoch: 49. Train Loss: 0.7071495652198792. Val Loss: 0.7053213119506836
# Epoch: 50. Train Loss: 0.7070063948631287. Val Loss: 0.7053213119506836
# Epoch: 51. Train Loss: 0.7071317434310913. Val Loss: 0.7053213119506836
# Epoch: 52. Train Loss: 0.7074495553970337. Val Loss: 0.7053213119506836
# Epoch: 53. Train Loss: 0.7077537775039673. Val Loss: 0.7053213119506836
# Epoch: 54. Train Loss: 0.7076966762542725. Val Loss: 0.7053213119506836
# Epoch: 55. Train Loss: 0.7078417539596558. Val Loss: 0.7053213119506836
# Epoch: 56. Train Loss: 0.7077699899673462. Val Loss: 0.7053213119506836
# Epoch: 57. Train Loss: 0.7071828246116638. Val Loss: 0.7053213119506836
# Epoch: 58. Train Loss: 0.707434892654419. Val Loss: 0.7053213119506836
# Epoch: 59. Train Loss: 0.7071628570556641. Val Loss: 0.7053213119506836
# Epoch: 60. Train Loss: 0.7073607444763184. Val Loss: 0.7053213119506836

# %%
# 執行攻擊並顯示結果
reconstructed_image = model_inversion_attack(model_ndp, (1, 1, im_height, im_width))
plt.imshow(reconstructed_image[0][0].cpu().detach().numpy(), cmap='gray')
plt.title("Reconstructed Image")
plt.show()
# Out:
# Attack Iteration 0, Loss: -14.71304988861084
# Attack Iteration 100, Loss: -17.304828643798828
# Attack Iteration 200, Loss: -19.638378143310547
# Attack Iteration 300, Loss: -21.83660888671875
# Attack Iteration 400, Loss: -23.936887741088867
# Attack Iteration 500, Loss: -25.988880157470703
# Attack Iteration 600, Loss: -28.02093505859375
# Attack Iteration 700, Loss: -30.059898376464844
# Attack Iteration 800, Loss: -32.07958221435547
# Attack Iteration 900, Loss: -34.095645904541016
# Attack Iteration 1000, Loss: -36.111427307128906
# Attack Iteration 1100, Loss: -38.13288879394531
# Attack Iteration 1200, Loss: -40.15087127685547
# Attack Iteration 1300, Loss: -42.14636993408203
# Attack Iteration 1400, Loss: -44.139217376708984
# Attack Iteration 1500, Loss: -46.131893157958984
# Attack Iteration 1600, Loss: -48.11233901977539
# Attack Iteration 1700, Loss: -50.08937072753906
# Attack Iteration 1800, Loss: -52.062774658203125
# Attack Iteration 1900, Loss: -54.0445671081543
# Attack Iteration 2000, Loss: -56.04052734375
# Attack Iteration 2100, Loss: -58.03840637207031
# Attack Iteration 2200, Loss: -60.024471282958984
# Attack Iteration 2300, Loss: -62.00754165649414
# Attack Iteration 2400, Loss: -63.993431091308594
# Attack Iteration 2500, Loss: -65.98934936523438
# Attack Iteration 2600, Loss: -67.99230194091797
# Attack Iteration 2700, Loss: -70.00476837158203
# Attack Iteration 2800, Loss: -72.00562286376953
# Attack Iteration 2900, Loss: -74.01092529296875

# %%
# 選取指定的初始影像，例如訓練數據中的第一張
initial_image = torch.tensor(X_train_shaped[0:1], dtype=torch.float32).to('cpu')  # 假設使用 CPU
# 執行攻擊並顯示初始影像
reconstructed_image = model_inversion_attack_no_randn(model_ndp, initial_image)

# 顯示攻擊結果影像
plt.imshow(reconstructed_image[0][0].cpu().detach().numpy(), cmap='gray')
plt.title("Reconstructed Image with Specified Initial Image")
plt.show()
# Out:
# Attack Iteration 0, Loss: -0.15750031173229218
# Attack Iteration 100, Loss: -0.9334259033203125
# Attack Iteration 200, Loss: -2.335453987121582
# Attack Iteration 300, Loss: -4.074379920959473
# Attack Iteration 400, Loss: -5.950767993927002
# Attack Iteration 500, Loss: -7.950796127319336
# Attack Iteration 600, Loss: -10.014119148254395
# Attack Iteration 700, Loss: -12.075328826904297
# Attack Iteration 800, Loss: -14.154047012329102
# Attack Iteration 900, Loss: -16.235549926757812
# Attack Iteration 1000, Loss: -18.30837631225586
# Attack Iteration 1100, Loss: -20.38146209716797
# Attack Iteration 1200, Loss: -22.4554500579834
# Attack Iteration 1300, Loss: -24.547269821166992
# Attack Iteration 1400, Loss: -26.645549774169922
# Attack Iteration 1500, Loss: -28.750682830810547
# Attack Iteration 1600, Loss: -30.861600875854492
# Attack Iteration 1700, Loss: -32.975608825683594
# Attack Iteration 1800, Loss: -35.09849548339844
# Attack Iteration 1900, Loss: -37.22734832763672
# Attack Iteration 2000, Loss: -39.359100341796875
# Attack Iteration 2100, Loss: -41.487586975097656
# Attack Iteration 2200, Loss: -43.60976028442383
# Attack Iteration 2300, Loss: -45.725318908691406
# Attack Iteration 2400, Loss: -47.84540939331055
# Attack Iteration 2500, Loss: -49.962249755859375
# Attack Iteration 2600, Loss: -52.06148910522461
# Attack Iteration 2700, Loss: -54.156673431396484
# Attack Iteration 2800, Loss: -56.25373840332031
# Attack Iteration 2900, Loss: -58.361976623535156
